# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt

# %%
img = cv2.imread("5.1 starwars.jpg (1).jpg")

# %%
plt.imshow(img)

# %%
blury_img = cv2.medianBlur(img,7)

# %%
plt.imshow(blury_img)

# %%
laplacian = cv2.Laplacian(blury_img , cv2.CV_64F).var() # resmin bulurlu olup olmadığını söyler

# %%
laplacian
# Out:
# 317.9994595426443

# %%
laplacian = cv2.Laplacian(img , cv2.CV_64F).var()

# %%
laplacian
# Out:
# 900.5680561195056
