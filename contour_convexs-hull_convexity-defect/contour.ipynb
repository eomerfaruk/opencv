# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt

# %%
img = cv2.imread("2.1 contour1.png (1).png")
plt.imshow(img)

# %%
gray = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)

# %%
_ , threshold = cv2.threshold(gray , 127,255 , cv2.THRESH_BINARY)

# %%
contours, _ = cv2.findContours(threshold , cv2.RETR_TREE , cv2.CHAIN_APPROX_SIMPLE)

# %%
contours
# Out:
# (array([[[  0,   0]],
#
#         [[  0, 240]],
#
#         [[413, 240]],
#
#         [[413,   0]]], dtype=int32),
#  array([[[ 34,  26]],
#
#         [[ 35,  25]],
#
#         [[204,  25]],
#
#         [[205,  26]],
#
#         [[211,  26]],
#
#         [[212,  27]],
#
#         [[212,  32]],
#
#         [[213,  33]],
#
#         [[213,  37]],
#
#         [[214,  38]],
#
#         [[214,  42]],
#
#         [[215,  43]],
#
#         [[215,  47]],
#
#         [[216,  48]],
#
#         [[216,  52]],
#
#         [[217,  53]],
#
#         [[217,  57]],
#
#         [[218,  58]],
#
#         [[218,  62]],
#
#         [[219,  63]],
#
#         [[219,  67]],
#
#         [[220,  68]],
#
#         [[220,  72]],
#
#         [[221,  73]],
#
#         [[221,  77]],
#
#         [[222,  78]],
#
#         [[222,  82]],
#
#         [[223,  83]],
#
#         [[223,  87]],
#
#         [[224,  88]],
#
#         [[224,  92]],
#
#         [[225,  93]],
#
#         [[225,  97]],
#
#         [[226,  98]],
#
#         [[226, 102]],
#
#         [[227, 103]],
#
#         [[227, 107]],
#
#         [[317, 107]],
#
#         [[319, 109]],
#
#         [[319, 111]],
#
#         [[317, 113]],
#
#         [[317, 160]],
#
#         [[317, 159]],
#
#         [[318, 158]],
#
#         [[318, 157]],
#
#         [[320, 155]],
#
#         [[320, 154]],
#
#         [[321, 153]],
#
#         [[321, 152]],
#
#         [[322, 151]],
#
#         [[322, 150]],
#
#         [[323, 149]],
#
#         [[323, 148]],
#
#         [[324, 147]],
#
#         [[324, 146]],
#
#         [[326, 144]],
#
#         [[326, 143]],
#
#         [[327, 142]],
#
#         [[327, 141]],
#
#         [[328, 140]],
#
#         [[328, 139]],
#
#         [[329, 138]],
#
#         [[329, 137]],
#
#         [[331, 135]],
#
#         [[331, 134]],
#
#         [[332, 133]],
#
#         [[332, 132]],
#
#         [[333, 131]],
#
#         [[333, 130]],
#
#         [[334, 129]],
#
#         [[334, 128]],
#
#         [[336, 126]],
#
#         [[336, 125]],
#
#         [[337, 124]],
#
#         [[337, 123]],
#
#         [[338, 122]],
#
#         [[338, 121]],
#
#         [[339, 120]],
#
#         [[339, 119]],
#
#         [[341, 117]],
#
#         [[341, 116]],
#
#         [[342, 115]],
#
#         [[342, 114]],
#
#         [[343, 113]],
#
#         [[343, 112]],
#
#         [[344, 111]],
#
#         [[344, 110]],
#
#         [[345, 109]],
#
#         [[345, 108]],
#
#         [[347, 106]],
#
#         [[347, 105]],
#
#         [[348, 104]],
#
#         [[348, 103]],
#
#         [[349, 102]],
#
#         [[349, 101]],
#
#         [[350, 100]],
#
#         [[350,  99]],
#
#         [[352,  97]],
#
#         [[352,  96]],
#
#         [[353,  95]],
#
#         [[353,  94]],
#
#         [[354,  93]],
#
#         [[354,  92]],
#
#         [[355,  91]],
#
#         [[355,  90]],
#
#         [[357,  88]],
#
#         [[357,  87]],
#
#         [[349,  79]],
#
#         [[349,  78]],
#
#         [[331,  60]],
#
#         [[331,  59]],
#
#         [[312,  40]],
#
#         [[312,  39]],
#
#         [[305,  32]],
#
#         [[303,  34]],
#
#         [[303,  35]],
#
#         [[300,  38]],
#
#         [[300,  39]],
#
#         [[298,  41]],
#
#         [[298,  42]],
#
#         [[295,  45]],
#
#         [[295,  46]],
#
#         [[293,  48]],
#
#         [[293,  49]],
#
#         [[290,  52]],
#
#         [[290,  53]],
#
#         [[288,  55]],
#
#         [[288,  56]],
#
#         [[285,  59]],
#
#         [[285,  60]],
#
#         [[282,  63]],
#
#         [[282,  64]],
#
#         [[280,  66]],
#
#         [[280,  67]],
#
#         [[277,  70]],
#
#         [[277,  71]],
#
#         [[275,  73]],
#
#         [[275,  74]],
#
#         [[272,  77]],
#
#         [[272,  78]],
#
#         [[270,  80]],
#
#         [[270,  81]],
#
#         [[267,  84]],
#
#         [[267,  85]],
#
#         [[265,  87]],
#
#         [[265,  88]],
#
#         [[262,  91]],
#
#         [[262,  92]],
#
#         [[257,  97]],
#
#         [[255,  97]],
#
#         [[253,  95]],
#
#         [[253,  93]],
#
#         [[252,  92]],
#
#         [[252,  89]],
#
#         [[251,  88]],
#
#         [[251,  86]],
#
#         [[250,  85]],
#
#         [[250,  82]],
#
#         [[249,  81]],
#
#         [[249,  78]],
#
#         [[248,  77]],
#
#         [[248,  75]],
#
#         [[247,  74]],
#
#         [[247,  71]],
#
#         [[246,  70]],
#
#         [[246,  68]],
#
#         [[245,  67]],
#
#         [[245,  64]],
#
#         [[244,  63]],
#
#         [[244,  60]],
#
#         [[243,  59]],
#
#         [[243,  57]],
#
#         [[242,  56]],
#
#         [[242,  53]],
#
#         [[241,  52]],
#
#         [[241,  50]],
#
#         [[240,  49]],
#
#         [[240,  46]],
#
#         [[239,  45]],
#
#         [[239,  42]],
#
#         [[238,  41]],
#
#         [[238,  39]],
#
#         [[237,  38]],
#
#         [[237,  35]],
#
#         [[236,  34]],
#
#         [[236,  26]],
#
#         [[237,  25]],
#
#         [[377,  25]],
#
#         [[378,  26]],
#
#         [[378, 209]],
#
#         [[377, 210]],
#
#         [[259, 210]],
#
#         [[258, 209]],
#
#         [[258, 202]],
#
#         [[250, 202]],
#
#         [[236, 188]],
#
#         [[235, 188]],
#
#         [[221, 174]],
#
#         [[220, 174]],
#
#         [[206, 160]],
#
#         [[205, 160]],
#
#         [[191, 146]],
#
#         [[190, 146]],
#
#         [[187, 143]],
#
#         [[187, 203]],
#
#         [[188, 204]],
#
#         [[188, 209]],
#
#         [[187, 210]],
#
#         [[114, 210]],
#
#         [[113, 209]],
#
#         [[116, 206]],
#
#         [[116, 205]],
#
#         [[117, 204]],
#
#         [[117, 202]],
#
#         [[118, 201]],
#
#         [[118, 195]],
#
#         [[117, 194]],
#
#         [[117, 192]],
#
#         [[116, 191]],
#
#         [[116, 190]],
#
#         [[109, 183]],
#
#         [[108, 183]],
#
#         [[106, 181]],
#
#         [[105, 181]],
#
#         [[104, 180]],
#
#         [[103, 180]],
#
#         [[102, 179]],
#
#         [[101, 179]],
#
#         [[100, 178]],
#
#         [[ 98, 178]],
#
#         [[ 97, 177]],
#
#         [[ 96, 177]],
#
#         [[ 95, 176]],
#
#         [[ 93, 176]],
#
#         [[ 92, 175]],
#
#         [[ 89, 175]],
#
#         [[ 88, 174]],
#
#         [[ 85, 174]],
#
#         [[ 84, 173]],
#
#         [[ 79, 173]],
#
#         [[ 78, 172]],
#
#         [[ 71, 172]],
#
#         [[ 70, 171]],
#
#         [[ 51, 171]],
#
#         [[ 50, 172]],
#
#         [[ 43, 172]],
#
#         [[ 42, 173]],
#
#         [[ 37, 173]],
#
#         [[ 36, 174]],
#
#         [[ 33, 174]],
#
#         [[ 32, 175]],
#
#         [[ 29, 175]],
#
#         [[ 28, 176]],
#
#         [[ 27, 175]],
#
#         [[ 27, 100]],
#
#         [[ 28,  99]],
#
#         [[ 34,  99]],
#
#         [[ 35,  98]],
#
#         [[106,  98]],
#
#         [[100,  92]],
#
#         [[ 99,  92]],
#
#         [[ 92,  85]],
#
#         [[ 91,  85]],
#
#         [[ 83,  77]],
#
#         [[ 82,  77]],
#
#         [[ 75,  70]],
#
#         [[ 74,  70]],
#
#         [[ 67,  63]],
#
#         [[ 66,  63]],
#
#         [[ 58,  55]],
#
#         [[ 57,  55]],
#
#         [[ 50,  48]],
#
#         [[ 49,  48]],
#
#         [[ 41,  40]],
#
#         [[ 40,  40]],
#
#         [[ 32,  32]],
#
#         [[ 32,  31]],
#
#         [[ 33,  30]],
#
#         [[ 34,  30]]], dtype=int32))

# %%
cv2.drawContours(img , contours , -1 ,(0,0,255),3 )
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        ...,
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]]], dtype=uint8)

# %%
plt.imshow(img)
