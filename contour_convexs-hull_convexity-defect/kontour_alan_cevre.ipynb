# %%
import cv2 
import numpy as np  
from matplotlib import pyplot as plt

# %%
img = cv2.imread("15.2 contour.png.png")
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
_ , thresh = cv2.threshold(gray , 127 ,255, cv2.THRESH_BINARY)

# %%
plt.imshow(img)

# %%
contours ,_ = cv2.findContours(thresh , cv2.RETR_TREE , cv2.CHAIN_APPROX_SIMPLE)

# %%
M = cv2.moments(contours[0]) #konturun özelliklerine erişildi

# %%
area = cv2.contourArea(contours[0]) # kontur alanını verir

# %%
area
# Out:
# 89744.0

# %%
M  = cv2.moments(contours[0])

# %%
M["m00"]
# Out:
# 89744.0

# %%
perimeter = cv2.arcLength(contours[0],True) # kontur cevre hesabı

# %%
perimeter
# Out:
# 1200.0
