# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt

# %%
img = cv2.imread("14.1 smile.jpg.jpg")

# %%
plt.imshow(img)

# %%
color = img[:,:,0]

# %%
plt.imshow(color) # img görüntüsünün mavi kanalını gösterir

# %%
color = img[150,200] #150 ye 200 kordinatındaki pikselinin renk değerleri verilir
color # 3 tane değer vermesinin sebebi 3 kanallı olması
# Out:
# array([249, 245, 234], dtype=uint8)

# %%
img.shape
# Out:
# (426, 640, 3)

# %%
blue= img[420,500,0] # görüntünün mavi kanalındaki renk değerini verir
blue
# Out:
# 57

# %%
green = img[230,400,1]# görüntünün yesil kanalındaki renk değerini verir
green
# Out:
# 166

# %%
red = img[233,333,2]# görüntünün kırmızı kanalındaki renk değerini verir
red
# Out:
# 188

# %%
img [330,200,0] = 255 # mavi kanalındaki bir piksele yeni değer (renk) atama

# %%
img [330,200,0]
# Out:
# 255

# %%
blue1 = img.item(150,200,0)
blue1
# Out:
# 249

# %%
img[150,200,0]
# Out:
# 249

# %%
img.itemset((150,200,0) , 172) # görüntünün mavi kanalındaki belirtilen pikselinine 172 değeri  atanır

# %%
img[150,200,0]
# Out:
# 172
