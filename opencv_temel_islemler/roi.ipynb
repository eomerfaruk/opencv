# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt

# %%
img = cv2.imread("14.1 smile.jpg.jpg")
plt.imshow(img)

# %%
roi_img = img[50:350,200:420] #görüntüden yüz olan kısmının görüntüsünü aldık
plt.imshow(roi_img)
