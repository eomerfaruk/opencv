# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt

# %%
img = cv2.imread("1.1 aircraft.jpg.jpg")

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img ,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img , cv2.COLOR_BGR2HSV)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)
